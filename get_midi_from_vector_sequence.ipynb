# %%
import mido
TICKS_PER_BEAT = 480
TEMPO = int(mido.bpm2tempo(120))

# %%
# %run 'get_training_data.ipynb'
# Out:
#  > 25/100 files loaded.
# Training data too short: PkmRB-Item2.mid. len(vector)=50
#  > 50/100 files loaded.
#  > 75/100 files loaded.
#  > 100/100 files loaded.

# %%
def get_track_sequences(vector_sequence):
    """Get note sequences for each track from vector sequence output from RNN.

    Args:
       vector_sequence: List of one-hot vectors containing 128 * NUM_TRACKS note_on events, 128 * NUM_TRACKS note_off events,
        and NUM_TIMESHIFTS timeshift events in intervals of 1/4 of a beat each.
       
    Returns:
        List of track vector sequences.
    """
    track_sequences = [[] for _ in range(NUM_TRACKS)]
    start_time = 0
    for vector in vector_sequence:
        index = np.nonzero(vector == 1)[0][0]
        # vector is a time event.
        if index >= NUM_MIDI_PITCHES * 2 * NUM_TRACKS:
            num_beats = (index - NUM_MIDI_PITCHES * 2 * NUM_TRACKS + 1) / NUM_TIMESHIFTS
            start_time += num_beats
        else:
            # vector is a note_off event.
            if index >= NUM_MIDI_PITCHES * NUM_TRACKS:
                note_type = 'note_off'
                index -= NUM_MIDI_PITCHES * NUM_TRACKS
            # vector is a note_on event.
            else:
                note_type = 'note_on'
            track_num = int(index / NUM_MIDI_PITCHES)
            note = index % NUM_MIDI_PITCHES
            track_sequences[track_num].append({"type": note_type, "note": note, "start_time": start_time})
            time_delay = 0
            
    return track_sequences

# %%
def get_midi_from_vector_sequence(track_sequences):
    """Get midi from track sequences.

    Args:
       track_sequences: List of vector sequences for each track.
       
    Returns:
        MidiFile object.
    """
    mid = mido.MidiFile()
    tracks = [mido.MidiTrack() for _ in range(NUM_TRACKS)]
    mid.tracks.extend(tracks)

    for i, ts in enumerate(track_sequences):
        prev_start_time = 0
        for event in ts:
            time = event["start_time"] - prev_start_time
            prev_start_time = event["start_time"]
            # I picked a random number for velocity.
            mid.tracks[i].append(mido.Message(event["type"], note=event["note"], velocity=50,
                                              time=int(time * TICKS_PER_BEAT)))
    
    return mid

# %%
def vector_to_midi(vector_sequence):
    """Get midi file from vector sequence output from RNN.

    Args:
       vector_sequence: List of one-hot vectors containing 128 * NUM_TRACKS note_on events, 128 * NUM_TRACKS note_off events,
        and NUM_TIMESHIFTS timeshift events in intervals of 1/4 of a beat each.
       
    Returns:
        MidiFile object.
    """
    track_sequences = get_track_sequences(vector_sequence)
    return get_midi_from_vector_sequence(track_sequences)

# %%
training_filename = 'training_data.txt'
get_training_data(0, 6000, training_filename=training_filename)
get_training_vectors_from_file(training_filename)
# Out:
#  > 25/5824 files loaded.
# Training data too short: PkmRB-Item2.mid. len(vector)=50
#  > 50/5824 files loaded.
#  > 75/5824 files loaded.
#  > 100/5824 files loaded.
# Training data too short: trojintr.mid. len(vector)=87
#  > 125/5824 files loaded.
# Faulty training data: DG_SMB_Main.mid. len(vector)=1179
#  > 150/5824 files loaded.
#  > 175/5824 files loaded.
#  > 200/5824 files loaded.
#  > 225/5824 files loaded.
#  > 250/5824 files loaded.
# Training data too short: Gpunchoutboss.mid. len(vector)=72
#  > 275/5824 files loaded.
# Training data too short: Zelda_-_Game_Over.mid. len(vector)=96
#  > 300/5824 files loaded.
# Training data too short: immortatatk.mid. len(vector)=45
#  > 325/5824 files loaded.
#  > 350/5824 files loaded.
#  > 375/5824 files loaded.
# Training data too short: Flag.mid. len(vector)=81
#  > 400/5824 files loaded.
# Training data too short: metroidit.mid. len(vector)=59
#  > 425/5824 files loaded.
#  > 450/5824 files loaded.
# Training data too short: rcproam_startrace.mid. len(vector)=97
#  > 475/5824 files loaded.
#  > 500/5824 files loaded.
#  > 525/5824 files loaded.
# Training data too short: smb3airv.mid. len(vector)=75
#  > 550/5824 files loaded.
#  > 575/5824 files loaded.
#  > 600/5824 files loaded.
#  > 625/5824 files loaded.
# Training data too short: sesamestreetmoon.mid. len(vector)=46
#  > 650/5824 files loaded.
# Training data too short: sr_gameover.mid. len(vector)=82
#  > 675/5824 files loaded.
# Faulty training data: vampire_killer(1).mid. len(vector)=8831
#  > 700/5824 files loaded.
#  > 725/5824 files loaded.
#  > 750/5824 files loaded.
# Training data too short: PkmGS-Delete.mid. len(vector)=50
#  > 775/5824 files loaded.
#  > 800/5824 files loaded.
#  > 825/5824 files loaded.
#  > 850/5824 files loaded.
#  > 875/5824 files loaded.
#  > 900/5824 files loaded.
# Training data too short: Castlevania_Game_Over.mid. len(vector)=84
#  > 925/5824 files loaded.
#  > 950/5824 files loaded.
#  > 975/5824 files loaded.
#  > 1000/5824 files loaded.
#  > 1025/5824 files loaded.
#  > 1050/5824 files loaded.
#  > 1075/5824 files loaded.
#  > 1100/5824 files loaded.
#  > 1125/5824 files loaded.
#  > 1150/5824 files loaded.
#  > 1175/5824 files loaded.
#  > 1200/5824 files loaded.
#  > 1225/5824 files loaded.
#  > 1250/5824 files loaded.
#  > 1275/5824 files loaded.
# Training data too short: Wl2-levelend.mid. len(vector)=65
#  > 1300/5824 files loaded.
#  > 1325/5824 files loaded.
#  > 1350/5824 files loaded.
#  > 1375/5824 files loaded.
#  > 1400/5824 files loaded.
#  > 1425/5824 files loaded.
#  > 1450/5824 files loaded.
#  > 1475/5824 files loaded.
#  > 1500/5824 files loaded.
#  > 1525/5824 files loaded.
# Training data too short: Wilymap5.mid. len(vector)=80
#  > 1550/5824 files loaded.
#  > 1575/5824 files loaded.
#  > 1600/5824 files loaded.
#  > 1625/5824 files loaded.
#  > 1650/5824 files loaded.
#  > 1675/5824 files loaded.
#  > 1700/5824 files loaded.
#  > 1725/5824 files loaded.
#  > 1750/5824 files loaded.
# Training data too short: smb3nspade.mid. len(vector)=96
#  > 1775/5824 files loaded.
#  > 1800/5824 files loaded.
#  > 1825/5824 files loaded.
#  > 1850/5824 files loaded.
# Training data too short: POsoda.mid. len(vector)=90
# Faulty training data: DarkMan2.mid. len(vector)=2686
#  > 1875/5824 files loaded.
# Training data too short: Wilymap6.mid. len(vector)=80
#  > 1900/5824 files loaded.
#  > 1925/5824 files loaded.
#  > 1950/5824 files loaded.
#  > 1975/5824 files loaded.
#  > 2000/5824 files loaded.
#  > 2025/5824 files loaded.
# Training data too short: 17-GameOver.mid. len(vector)=91
#  > 2050/5824 files loaded.
# Training data too short: 18-WilyIntro.mid. len(vector)=98
#  > 2075/5824 files loaded.
# Training data too short: FDS_BIOS_-_Startup.mid. len(vector)=74
#  > 2100/5824 files loaded.
# Training data too short: smb-go.mid. len(vector)=81
#  > 2125/5824 files loaded.
#  > 2150/5824 files loaded.
#  > 2175/5824 files loaded.
#  > 2200/5824 files loaded.
#  > 2225/5824 files loaded.
# Training data too short: mhsgc.mid. len(vector)=82
#  > 2250/5824 files loaded.
#  > 2275/5824 files loaded.
#  > 2300/5824 files loaded.
#  > 2325/5824 files loaded.
#  > 2350/5824 files loaded.
#  > 2375/5824 files loaded.
#  > 2400/5824 files loaded.
# Training data too short: NinjaJajamaruKunLevelStart.mid. len(vector)=96
# Training data too short: Golgo_13_Top_Secret_Episode-Game_Over.mid. len(vector)=72
#  > 2425/5824 files loaded.
#  > 2450/5824 files loaded.
#  > 2475/5824 files loaded.
#  > 2500/5824 files loaded.
#  > 2525/5824 files loaded.
#  > 2550/5824 files loaded.
#  > 2575/5824 files loaded.
#  > 2600/5824 files loaded.
#  > 2625/5824 files loaded.
#  > 2650/5824 files loaded.
#  > 2675/5824 files loaded.
# Faulty training data: Battleofholy.mid. len(vector)=1335
#  > 2700/5824 files loaded.
# Training data too short: GuardianLegend_GameOver.mid. len(vector)=79
# Faulty training data: DG_C3_Vampire_Killer.mid. len(vector)=79
#  > 2725/5824 files loaded.
# Training data too short: DKmiss1.mid. len(vector)=87
#  > 2750/5824 files loaded.
# Training data too short: gbwl3glflose.mid. len(vector)=75
#  > 2775/5824 files loaded.
# Faulty training data: DG_C3_Evergreen.mid. len(vector)=2092
#  > 2800/5824 files loaded.
#  > 2825/5824 files loaded.
#  > 2850/5824 files loaded.
#  > 2875/5824 files loaded.
#  > 2900/5824 files loaded.
# Training data too short: MM3ProtomanWhistle.mid. len(vector)=64
#  > 2925/5824 files loaded.
#  > 2950/5824 files loaded.
#  > 2975/5824 files loaded.
#  > 3000/5824 files loaded.
#  > 3025/5824 files loaded.
#  > 3050/5824 files loaded.
#  > 3075/5824 files loaded.
# Training data too short: m2_Item.mid. len(vector)=95
#  > 3100/5824 files loaded.
#  > 3125/5824 files loaded.
#  > 3150/5824 files loaded.
# Training data too short: Jaws_get-ready.mid. len(vector)=95
#  > 3175/5824 files loaded.
# Training data too short: Gbgmovr3.mid. len(vector)=89
# Training data too short: gzilla_soundtest5.mid. len(vector)=69
#  > 3200/5824 files loaded.
#  > 3225/5824 files loaded.
#  > 3250/5824 files loaded.
#  > 3275/5824 files loaded.
#  > 3300/5824 files loaded.
#  > 3325/5824 files loaded.
#  > 3350/5824 files loaded.
# Training data too short: PkmGS-Badge.mid. len(vector)=84
#  > 3375/5824 files loaded.
#  > 3400/5824 files loaded.
#  > 3425/5824 files loaded.
#  > 3450/5824 files loaded.
#  > 3475/5824 files loaded.
#  > 3500/5824 files loaded.
#  > 3525/5824 files loaded.
#  > 3550/5824 files loaded.
# Training data too short: ANTARLevel_Complete.mid. len(vector)=84
# Training data too short: 22-WilyDefeat.mid. len(vector)=69
#  > 3575/5824 files loaded.
#  > 3600/5824 files loaded.
# Training data too short: Zeldalea.mid. len(vector)=62
#  > 3625/5824 files loaded.
# Training data too short: PkmGS-Caught.mid. len(vector)=52
#  > 3650/5824 files loaded.
#  > 3675/5824 files loaded.
#  > 3700/5824 files loaded.
#  > 3725/5824 files loaded.
#  > 3750/5824 files loaded.
#  > 3775/5824 files loaded.
#  > 3800/5824 files loaded.
#  > 3825/5824 files loaded.
#  > 3850/5824 files loaded.
# Training data too short: PmanShort.mid. len(vector)=80
# Training data too short: PkmRB-Caught.mid. len(vector)=39
#  > 3875/5824 files loaded.
#  > 3900/5824 files loaded.
#  > 3925/5824 files loaded.
#  > 3950/5824 files loaded.
#  > 3975/5824 files loaded.
#  > 4000/5824 files loaded.
# Training data too short: PkmGS-Pokedex2.mid. len(vector)=33
#  > 4025/5824 files loaded.
# Faulty training data: Maxhawk.mid. len(vector)=917
#  > 4050/5824 files loaded.
#  > 4075/5824 files loaded.
# Training data too short: bttf2go.mid. len(vector)=37
# Training data too short: kidnikiremix_level-intro.mid. len(vector)=98
#  > 4100/5824 files loaded.
# Training data too short: duckhuntlevelcomplete.mid. len(vector)=97
#  > 4125/5824 files loaded.
#  > 4150/5824 files loaded.
#  > 4175/5824 files loaded.
#  > 4200/5824 files loaded.
#  > 4225/5824 files loaded.
#  > 4250/5824 files loaded.
# Faulty training data: DG_SML_Muda.mid. len(vector)=2146
#  > 4275/5824 files loaded.
#  > 4300/5824 files loaded.
#  > 4325/5824 files loaded.
# Training data too short: 04-MM2StageIntro.mid. len(vector)=85
#  > 4350/5824 files loaded.
# Training data too short: smbdeath.mid. len(vector)=33
# Training data too short: DKvctory.mid. len(vector)=96
#  > 4375/5824 files loaded.
#  > 4400/5824 files loaded.
#  > 4425/5824 files loaded.
#  > 4450/5824 files loaded.
#  > 4475/5824 files loaded.
#  > 4500/5824 files loaded.
# Training data too short: mkii_zb_fat_gb.mid. len(vector)=26
#  > 4525/5824 files loaded.
# Training data too short: smb3kinr.mid. len(vector)=95
#  > 4550/5824 files loaded.
#  > 4575/5824 files loaded.
# Training data too short: Mm6vict2.mid. len(vector)=94
#  > 4600/5824 files loaded.
#  > 4625/5824 files loaded.
#  > 4650/5824 files loaded.
#  > 4675/5824 files loaded.
#  > 4700/5824 files loaded.
#  > 4725/5824 files loaded.
# Training data too short: cvLostLife.mid. len(vector)=64
#  > 4750/5824 files loaded.
# Training data too short: Metrma.mid. len(vector)=77
#  > 4775/5824 files loaded.
#  > 4800/5824 files loaded.
#  > 4825/5824 files loaded.
#  > 4850/5824 files loaded.
# Training data too short: zelda-go.mid. len(vector)=70
# Faulty training data: DG_MM5_Darkman.mid. len(vector)=374
#  > 4875/5824 files loaded.
# Training data too short: mm3protw.mid. len(vector)=80
#  > 4900/5824 files loaded.
#  > 4925/5824 files loaded.
# Training data too short: POtbout.mid. len(vector)=72
#  > 4950/5824 files loaded.
# Training data too short: Deleting_Photo.mid. len(vector)=75
#  > 4975/5824 files loaded.
#  > 5000/5824 files loaded.
# Training data too short: STANLevel_Complete.mid. len(vector)=75
# Training data too short: Chosen1.mid. len(vector)=89
#  > 5025/5824 files loaded.
# Training data too short: ng2_lahj.mid. len(vector)=54
# Training data too short: dk-stagestart.mid. len(vector)=56
#  > 5050/5824 files loaded.
#  > 5075/5824 files loaded.
# Training data too short: 06-StageIntro.mid. len(vector)=66
#  > 5100/5824 files loaded.
# Training data too short: Super_Mario_Bros._-_Flag.mid. len(vector)=81
#  > 5125/5824 files loaded.
# Training data too short: sting-in.mid. len(vector)=97
#  > 5150/5824 files loaded.
#  > 5175/5824 files loaded.
#  > 5200/5824 files loaded.
#  > 5225/5824 files loaded.
#  > 5250/5824 files loaded.
# Training data too short: BeatBoss.mid. len(vector)=96
#  > 5275/5824 files loaded.
#  > 5300/5824 files loaded.
#  > 5325/5824 files loaded.
# Training data too short: ml1prize.mid. len(vector)=94
# Training data too short: Gb2chose.mid. len(vector)=86
#  > 5350/5824 files loaded.
#  > 5375/5824 files loaded.
#  > 5400/5824 files loaded.
#  > 5425/5824 files loaded.
#  > 5450/5824 files loaded.
# Faulty training data: Super_Mario_Bros_-_Castle_(Techno_Gabber_remix).mid. len(vector)=1230
#  > 5475/5824 files loaded.
# Faulty training data: Balloon_Fight_-_Main_Theme_(Dancing_Balloon!_remix).mid. len(vector)=861
#  > 5500/5824 files loaded.
# Training data too short: pkmntrans.mid. len(vector)=96
#  > 5525/5824 files loaded.
#  > 5550/5824 files loaded.
#  > 5575/5824 files loaded.
#  > 5600/5824 files loaded.
#  > 5625/5824 files loaded.
# Training data too short: DraculasCurse_Prayer.mid. len(vector)=93
#  > 5650/5824 files loaded.
#  > 5675/5824 files loaded.
# Faulty training data: DG_C3_Stream.mid. len(vector)=2070
#  > 5700/5824 files loaded.
#  > 5725/5824 files loaded.
#  > 5750/5824 files loaded.
#  > 5775/5824 files loaded.
#  > 5800/5824 files loaded.
# (array([[7],
#         [7],
#         [4],
#         ...,
#         [7],
#         [7],
#         [1]]),
#  ['FridayThe13th_-_MapDark.mid',
#   'gymleader2.mid',
#   'Zelda_IV_-_Tail_Cave.mid',
#   'cv1-4.mid',
#   'MM3-Snake_Man.mid',
#   'smlboss.mid',
#   'molemania_snow.mid',
#   'dw4batl.mid',
#   'mm1wily2.mid',
#   'dd-intermission.mid',
#   '1999.mid',
#   'FiremanByCryogen.mid',
#   'Heavy_Barrel_-_Boss_BGM.mid',
#   'Train.mid',
#   'Wizards_and_Warriors_II_Ironsword_-_Wind_Elemental.mid',
#   'DK-07-Iceberg.mid',
#   'supercend.mid',
#   'DW4TALN.mid',
#   'shatter2_v10.mid',
#   'Spark_Man.mid',
#   'boss-drums.mid',
#   'T_NinjaGaidenShadow_Stage3.mid',
#   'dd2-mission5.mid',
#   'Grad21_2_v2.mid',
#   'elm_street_metal.mid',
#   'Sparkman6969.mid',
#   'Rick_Rude.mid',
#   '12-Magnetman.mid',
#   'Bbtitle2.mid',
#   'WizWar2Lvl1.mid',
#   'StarTropics-alien_ship.mid',
#   'Gbboss.mid',
#   'bohmagna.mid',
#   'wl2end.mid',
#   'TheLegendRemixed.mid',
#   'lf-st4.mid',
#   'IcarusGBW1.mid',
#   'gradius7.mid',
#   'Klxtitle.mid',
#   'CentaurmanFulminantMix.mid',
#   'Silver_BeforeTheContest.mid',
#   'mario_3.mid',
#   'smb_techno.mid',
#   'DKworld1.mid',
#   'Wily4.mid',
#   'Zelda_IV_-_Catfishs_Maw.mid',
#   'Z4mambo.mid',
#   'KickMaster-Sector2_XG.mid',
#   'Wiz1combat.mid',
#   'la1.mid',
#   'K-clear.mid',
#   'BKGB_FinalBoss_Kio_4.mid',
#   'Final_Battle.mid',
#   'z_OofSsnakesremains.mid',
#   'dragonintrob.mid',
#   'kouha-train.mid',
#   'flash.mid',
#   'SaGaon.mid',
#   'tennisgbtitlescreen.mid',
#   'IP_Tetris_Title.mid',
#   'ShadowHold.mid',
#   'SMB3_MusicBox.mid',
#   'elec.mid',
#   'kiwi-g.mid',
#   'MKMINE.mid',
#   'c3map.mid',
#   'Micro_Machines_1_and_2_Twin_Turbo_-_Course_Select.mid',
#   'Pitfall_-_Underground_Caverns.mid',
#   'DL_Route10.mid',
#   'startrek(2).mid',
#   'mm2_weaponget.mid',
#   'Wario_Syrup_Castle.mid',
#   'T_Tsub29.mid',
#   'sr_ending.mid',
#   'z_OofSselection.mid',
#   'c1vamp.mid',
#   'earthbound_0_(Mother)_-_snow_man.mid',
#   'nesmm5_gravityman.mid',
#   'cas-kid_.mid',
#   'Metalman.mid',
#   'uninvit2.mid',
#   'PkmGS-Enc4.mid',
#   'SR388_SSBB_Remix.mid',
#   'c3stg4.mid',
#   'Zelda_2-_Battle_Stage.mid',
#   'DIZZY.mid',
#   '1943lost (1).mid',
#   'Megaman3-Snakeman.mid',
#   'schzch5.mid',
#   'starwar_han.mid',
#   'ff2jbat4.mid',
#   'Castlevania_Stalker.mid',
#   'smb3000.mid',
#   'Zelda_NES_Title.mid',
#   'DKmonkey.mid',
#   'Astyanax-Redwood.mid',
#   'PkmGS-MtMoon.mid',
#   'lalev3.mid',
#   'preluderemix.mid',
#   'Gauntlet_Remix_II.mid',
#   'bomb2stg1.mid',
#   'TNTNUNN.mid',
#   'GQOverworld.mid',
#   'RR_Music3.mid',
#   'yc_1p_music_b.mid',
#   'tmnt2stg1.mid',
#   'Sm1cave.mid',
#   'cva-st4.mid',
#   'quickman_samba.mid',
#   'GLegend_Lander.mid',
#   'Sg-bqpiano.mid',
#   'Hebereke-Boss3.mid',
#   'The_Story_.mid',
#   'ddtheme.mid',
#   'mm3magnt.mid',
#   'PkmGS-Rocket.mid',
#   'SilenceofDaylight.mid',
#   'WizStore.mid',
#   'BB-MM2_Bubble_Man.mid',
#   'Faxdeadremix.mid',
#   'mcklvl3.mid',
#   'Crystalis_-_Tower.mid',
#   'T_Rygar7.mid',
#   'duck_hunt.mid',
#   'GargoyleshouseV3.mid',
#   'PkmGS-Hideout.mid',
#   'Cloudy_Park.mid',
#   'G_Megaman3_StageSelection.mid',
#   'PkmGS-Battle1.mid',
#   'Ts_boss.mid',
#   'dkl-clouds.mid',
#   'T_RockMan6_TomahawkMan_v13b.mid',
#   'Tetris_3.mid',
#   'KirbyDreamLand-CastleLololo.mid',
#   'sml2bns.mid',
#   'S-market.mid',
#   'Metal1_2.mid',
#   'CVL_Stage4_v3.mid',
#   'Amagon-Final_Boss.mid',
#   'Pk_gs_b4tbatt.mid',
#   'HallOfFame.mid',
#   'T_WaiWaiWorld_Kong.mid',
#   'KW-moai.mid',
#   'MM5_Charge_Man-KMv1-2.mid',
#   'batman-Brass.mid',
#   'KDL2Kingdedede.mid',
#   'Hebereke_-_Tundra.mid',
#   'SRnR_-_Stage_02.mid',
#   'faxtitle.mid',
#   'ng1_2-2.mid',
#   'DKworld9-(2).mid',
#   'Kidend.mid',
#   'ml1airpl.mid',
#   'SML2SpaceZoneMapTUK.mid',
#   'Poketrainer.mid',
#   'wily2dag.mid',
#   'Boss2.mid',
#   'LASFShrn.mid',
#   'bkgb_title_kio_7 (1).mid',
#   'Kbblvl03.mid',
#   'KIst4.mid',
#   'StoneMan.mid',
#   'PkmGS-Rival.mid',
#   'Francontinue.mid',
#   'tetrisnameentrynes.mid',
#   'T_TecmoWrestling_MatchTheme01.mid',
#   'Stage_Select.mid',
#   'Bloody_Tears.mid',
#   'Dragonslairts.mid',
#   'ffalest.mid',
#   'ng2_3-2.mid',
#   'Viridian_City_Carnival (1).mid',
#   'alphamis.mid',
#   'contra.mid',
#   'Immortitle.mid',
#   'LOTW_Dungeon1.mid',
#   'CV3_-_Clockwork_-Remix-.mid',
#   'MKSPACE.mid',
#   'Waveman.mid',
#   'Zeldacha.mid',
#   '11-Topman.mid',
#   'tdxopt.mid',
#   'tmnt5.mid',
#   'Str2010.mid',
#   'Adventure_Island_II-Overworld_3.mid',
#   'Smbtheme.mid',
#   'Lolo3lvl.mid',
#   'Koholint_Island.mid',
#   'BOMB.mid',
#   'Btsurf.mid',
#   'GIJOEAF.mid',
#   'Sg_end.mid',
#   'gwg-gc2c.mid',
#   'Anticipation12.mid',
#   'MM2-Air_Man-ER.mid',
#   'startrop.mid',
#   'MM3_NeedleMan.mid',
#   'S_onoxb.mid',
#   'ff3darkworld.mid',
#   'archon_battle.mid',
#   'da_smb3-overworld2.mid',
#   'PKMNTCG2_-_RonaldXG.mid',
#   'Volcano_World.mid',
#   'ffaboss2.mid',
#   'SaGaon (1).mid',
#   'ff2jtow2.mid',
#   'OLhomealoneTreehouse.mid',
#   'CV3-_Dejavu.mid',
#   'DW3CAVE.mid',
#   'PowerbladeBoss.mid',
#   'gauntl-a.mid',
#   'Viridian_City_Carnival.mid',
#   'T_Crystalis_MapTheme105.mid',
#   'TJ_NinjaRyukenden_Lukifell.mid',
#   'TLoZ-LA-Overworld.mid',
#   'mbjwin.mid',
#   'RogerPark.mid',
#   'Burai_Fighter_-_Taxan.mid',
#   'tmnt2stg10.mid',
#   'metbrins.mid',
#   'rcr-bridge.mid',
#   'Ttauw.mid',
#   'finalbout.mid',
#   'Dont_Give_Up_Drums_Mix.mid',
#   'tmnt-dx.mid',
#   'T_NekketsuKakutoDensetsu_DoubleTiger.mid',
#   'surferXG.mid',
#   'Kbblvl02.mid',
#   'Dw1title.mid',
#   'Ttahfst.mid',
#   'Sm2th.mid',
#   'MM3_-_Skull_Castle_2.mid',
#   'T_Ryga10.mid',
#   'cbsc_swim.mid',
#   'st8nemoremix.mid',
#   'GSC_Azalea_Town.mid',
#   'bubble_ghost.mid',
#   'rc_outworld3rmx.mid',
#   'SRnR_-_Stage_03.mid',
#   'Illuminator.mid',
#   'WL3endboss.mid',
#   'Dragon_warrior3_select.mid',
#   'LufiaSBatt.mid',
#   '04-LightLab2.mid',
#   'sm3grass.mid',
#   'Boss_Selected.mid',
#   'bohgreen.mid',
#   'Metroid_-_BrinstarXG.mid',
#   'PkmGS-Lighthouse.mid',
#   'PkmRB-Indigo.mid',
#   'FQBM.mid',
#   'ANTARIntro.mid',
#   'Enemy.mid',
#   'tetris_2.mid',
#   'OoAAmbi.mid',
#   'guarleg_boss1.mid',
#   'Gremlins2_-_Stg5.mid',
#   'mcklvl2.mid',
#   'DL_Level2.mid',
#   'vkr.mid',
#   'papernes.mid',
#   'Sparkman_Advanced.mid',
#   'Ninja_Gaiden_Mine.mid',
#   'T_GuardianLegend_DeadSilence.mid',
#   'SML_4-1.mid',
#   'maintheme.mid',
#   'mario09.mid',
#   'clemens.mid',
#   'cdrr2fch.mid',
#   'Wrecking_Crew-Theme_GS.mid',
#   'PkmRB-Center.mid',
#   'wlbosslevels.mid',
#   'SYD.mid',
#   'Hebereke-Boss2.mid',
#   'kf-theme.mid',
#   'FFL2STW (1).mid',
#   'SMB_-_Underworld_-Remix-.mid',
#   'OLfantzoneround1.mid',
#   'A_Town_In_Chaos-DAY.mid',
#   'yc_1p_music_c.mid',
#   'StAnne.mid',
#   'Bub_Invincible.mid',
#   'PkmGS-Intro2.mid',
#   'DKhammer.mid',
#   'Lalev2.mid',
#   'pharaoh.mid',
#   'mk3_zb_character_gb.mid',
#   'airman2.mid',
#   'RR_Music2.mid',
#   'Hardman_Arranged.mid',
#   'SML_World_4.mid',
#   'gzilla_gameselect.mid',
#   'ff2jbat5.mid',
#   'Tomahawk.mid',
#   'Kung-Fu_Heroes-Stage_2-2.mid',
#   'WarioLand-StoveCanyonStage2.mid',
#   'CVBR_-_Evil_Gods.mid',
#   'G_Terminator2_Stage1.mid',
#   'lwdragon.mid',
#   'S-level8.mid',
#   'DD2L8DDIT.mid',
#   'T_Tsub14.mid',
#   'Ghosts_N_Goblins-Intro_2.mid',
#   'uninvit3.mid',
#   'c3stg5.mid',
#   'SuperMarioLand2FinalStage-MiguelMartins.mid',
#   'mcktitle.mid',
#   'PkmGS-Enc5.mid',
#   'ff3jworld.mid',
#   'superc3.mid',
#   'route-27-26-metal.mid',
#   'skullman.mid',
#   'sohshman.mid',
#   'NG_-_Act_2-2_-Remix-.mid',
#   'PkmRB-Cinnabar.mid',
#   'PkmGS-RadioLullaby.mid',
#   'armadillo_casino.mid',
#   'T_Batman_Stage2-1.mid',
#   'lahouse.mid',
#   'final_fantasy_adventure_title_screen__elaboration.mid',
#   'gzilla_bossdie.mid',
#   'KirbyBB_-_Stage10.mid',
#   'T_Tsub28.mid',
#   "Gargoyle's_Quest_Title_Theme.mid",
#   'LoZ_Title-KM.mid',
#   'DG_C3_Mad_Forest.mid',
#   'Wiz1Maze (1).mid',
#   'ng3_duel.mid',
#   'Magi_Boss_Battle.mid',
#   'BTDDLvl2.mid',
#   'windfis2.mid',
#   'z_OofSancientruins.mid',
#   'Prolog4b.mid',
#   'DKL_Temple_Stage-different-instruments.mid',
#   'SML_Ruins.mid',
#   'WarioLand2-DefeatFourDucks.mid',
#   'metmini2.mid',
#   'Gdklandboss.mid',
#   'Matoya.mid',
#   'T_MetalGear_PasswordTheme.mid',
#   'laboat.mid',
#   'c3stg6a.mid',
#   'Prolog6J.mid',
#   'Chaos_Temple_(4).mid',
#   'Wily5.mid',
#   'PkmGS-Violet.mid',
#   'OLfantzoneboss.mid',
#   'crysover2.mid',
#   'JDC_WFort2.mid',
#   'PokemonGS-Gym.mid',
#   'gradius6.mid',
#   'kdl2rick.mid',
#   'Donkey_Kong.mid',
#   'Creators_World.mid',
#   'SMLruin.mid',
#   'Peloponnesus.mid',
#   'wl3_endb.mid',
#   'Gauntlet_SongD.mid',
#   'Orange_Ocean-1.mid',
#   'yc_title.mid',
#   'lf-st5.mid',
#   'Mafat_Conspiracy-Danger.mid',
#   'Ml2pumpk.mid',
#   'dtwin.mid',
#   'MKTITLE.mid',
#   'gbc_mg_sm04_ragtime.mid',
#   'johto-gym-leader-battle.mid',
#   'ppggbcs5b.mid',
#   "Don't_Give_Up!_(Drums_Mix).mid",
#   'bbtitler.mid',
#   'ChipNDale2_-_FatCatHQ.mid',
#   'dd2-mission4.mid',
#   'Level_1.mid',
#   'ffadvmenu.mid',
#   'Action52CityofDoom.mid',
#   'im_op.mid',
#   'starwar_eisly.mid',
#   'ttas4int.mid',
#   'kouha-lvl4.mid',
#   '07-Metalman.mid',
#   'DW3FLY.mid',
#   'RYGAR4B.mid',
#   "Bard'sMelody.mid",
#   'T_CapcomQuiz_1943Theme_Remix.mid',
#   'Top_Guy.mid',
#   'MegaMan4Boss_-_Orchestral_Remix.mid',
#   'Sml2cart.mid',
#   'sectionz1.mid',
#   'T_MissionImpossible_Enemy.mid',
#   "faxanadu_-_king's_castle.mid",
#   'T_StriderHiryu_Generator.mid',
#   'cocoboss.mid',
#   'King_Hippo.mid',
#   'SML2-1.mid',
#   'G_GBMegaman1_PasswordScreen.mid',
#   'dkl2hive.mid',
#   'bc5.mid',
#   'mighty_final_fight-riverside.mid',
#   'FS2-BonusGame.mid',
#   'Groovy.mid',
#   'Coo_the_Owl.mid',
#   'Goonmaz.mid',
#   'dhgbboss.mid',
#   'holon.mid',
#   'Snbrost3.mid',
#   'airwolf_title.mid',
#   'snakerattle_highaltitude.mid',
#   'PkmGS-TheEnd.mid',
#   'JDC_FaxChurc.mid',
#   'Mt_tararanch1.mid',
#   'dd3level2.mid',
#   'dd2-mission6.mid',
#   'Top_Gun_-_Fuel_Plane.mid',
#   'WL2_Really_Final_ChapterV1.1.mid',
#   'Rambo_Intro.mid',
#   'CVL_Gears_and_Chains.mid',
#   'Golgo_13_Mafat_Conspiracy-Building_2.mid',
#   'rcrstatus.mid',
#   'PkmRB-Evolving.mid',
#   'GCVBR_-_Demo_2.mid',
#   'pokegsgymleader.mid',
#   '14-BossTheme2.mid',
#   'dklice.mid',
#   '10_Main_Theme_original_GM.mid',
#   'KirbyAdventure_-_ButterStageArranged.mid',
#   'GBclash.mid',
#   'Mm6mrx.mid',
#   'ng3_into.mid',
#   'gradius4.mid',
#   'T_TekkamanGB_Menu.mid',
#   'MarbleMadness0.mid',
#   'Wwtree.mid',
#   'ng1-1.mid',
#   'kungfu2.mid',
#   'bkidttle.mid',
#   'FFIII_Boss.mid',
#   'mggbcDormie.mid',
#   'Mm5weap.mid',
#   'PKMNRBY_-_LavenderTownDnBXG.mid',
#   'PkmGS-Bike.mid',
#   'Dragon_Warrior_Tantagel_Castle.mid',
#   'ff1end.mid',
#   'AI3-Thundercloud.mid',
#   'Megaman_2_Title.mid',
#   'ng2_asht.mid',
#   'Doomship.mid',
#   'mggbcEven.mid',
#   'AkumajouDensetsu_Prayer.mid',
#   'dkl3bltz.mid',
#   'Forest2.mid',
#   'Rockman3-WilysCastlePart3.mid',
#   'Action52DamBusters.mid',
#   'China.mid',
#   'drbtetris.mid',
#   'c3stga.mid',
#   'kdikarus.mid',
#   'dkc_hoard.mid',
#   'FFL2STW.mid',
#   'AoL_palace-V1-1.mid',
#   'cva2-crs.mid',
#   'ww1metal.mid',
#   'z_OofSgnarledroot.mid',
#   'PkmGS-Enc7.mid',
#   'T_SnakesRevenge_EnemyTrain_WinGroove.mid',
#   'rcrstreets.mid',
#   'Athena-Boss.mid',
#   'uninvit1.mid',
#   'T_Tsub16.mid',
#   'lotwboss.mid',
#   'ttagbmmsn.mid',
#   'crys-tower.mid',
#   'GuardianLegend_CrystalFlight.mid',
#   'Adventure_Island_II-Credits.mid',
#   'SMB3_Sea_Side-KM.mid',
#   'ffIIItime321.mid',
#   'Z4owl.mid',
#   'Marble_Madness_-_Level_3.mid',
#   'xkyKirby.mid',
#   'MetroidNES_Brinstar.mid',
#   'Aryuga (1).mid',
#   'tsbvwhsb.mid',
#   'pokeorch.mid',
#   'Kirby_2_Sad_End.mid',
#   'yc_1p_music_a.mid',
#   "Dive_Man_(Cecil's_Extended_Dance_Mix).mid",
#   'silvers3.mid',
#   'mm2w1m.mid',
#   'SML2Over.mid',
#   'T_Rygar4.mid',
#   'guarleg_boss3.mid',
#   'Ttahmtn.mid',
#   'MM5RobotSelect.mid',
#   'ff1flcst.mid',
#   'Amagon-Zone_4_Rain_Forest.mid',
#   'basement.mid',
#   'rcr-main.mid',
#   'UnknownMarioBrosThemeGameOverChoir.mid',
#   'FlashmanByCryogen.mid',
#   'palace2.mid',
#   'KirbyTechno.mid',
#   'palaces.mid',
#   'PkmGS-Azalea.mid',
#   'faxoverworld.mid',
#   'MM6CentaurArrangev2.mid',
#   'AFLevel_Intro.mid',
#   'wl-mt_teapot_level.mid',
#   'Hebereke-World.mid',
#   'PkmGS-Battle2.mid',
#   "z_OofSpoisonmoth'slair.mid",
#   'bb-Ending.mid',
#   'SRnR_-_Stage_01.mid',
#   'ng1_2-1.mid',
#   'Lightwd.mid',
#   'Adventure_Island_II-Bonus.mid',
#   'Level_8_-_Intruder_Excluder.mid',
#   'smb3nspd.mid',
#   'ml1bonus.mid',
#   'RK-Title.mid',
#   'GS_Rivial.mid',
#   'Pokemon_Gold_Champion_SSBB_Remix.mid',
#   'Ruins.mid',
#   'mm3shado.mid',
#   'Athena-Hell.mid',
#   'PyramidI.mid',
#   'wl2crdts.mid',
#   'simpsbs1.mid',
#   'KDstg2.mid',
#   'kidicboss1.mid',
#   'CV3_Dejavu.mid',
#   'kbb-stage9.mid',
#   'ThiefStore.mid',
#   'aspiration.mid',
#   'T_TecmoWrestling_MatchTheme02.mid',
#   'drm_feverremix.mid',
#   'T_HiryuNoKenIII_NextActTheme.mid',
#   'gauntl-c.mid',
#   'LowGmanTheTowerStage4.mid',
#   'Plantman2.mid',
#   'KickMaster_final_.mid',
#   'victory-V1.2.mid',
#   'Pktcmenu.mid',
#   'metroid_-_escape.mid',
#   'MM1-_Fireman.mid',
#   'ZeldaTechmid3.mid',
#   'kbb-credits.mid',
#   'gauntl-t.mid',
#   'Factory.mid',
#   'MG2.mid',
#   'gothic_zelda_theme.mid',
#   'Anticipation10.mid',
#   'tetris_piano.mid',
#   'shadow8.mid',
#   'ffl3Title01.mid',
#   'DKitem-t.mid',
#   'robowarrior_keepmoving.mid',
#   'Anticipation11.mid',
#   'T_SweetHome_LobbyTheme.mid',
#   'GBC-Boss.mid',
#   'ttahfrst.mid',
#   'Z4hen.mid',
#   'Zelda_IV_-_Eagles_Tower.mid',
#   'ContraForce-L4.mid',
#   'Wario_Land_Mt_Teapot.mid',
#   'Adventure_Island_II-Overworld_1.mid',
#   'PkmRB-Celadon.mid',
#   'Sabaron.mid',
#   'Wario_Water_Levels.mid',
#   'mike_tysons_punch-out_-_story_and_ending.mid',
#   'c3everg.mid',
#   'T_TecmoWrestling_MatchTheme03.mid',
#   'gauntl-b.mid',
#   'T_RoboWarrior_BonusRoomTheme.mid',
#   '1943BossWin.mid',
#   'Metroid_II_Credits_v3.mid',
#   'Adventure_Island_II-Island_Boss.mid',
#   'abadoxgo.mid',
#   'OLskyhawkbase.mid',
#   'kbb-stage8.mid',
#   'Golgo_13_Top_Secret_Episode-Maze.mid',
#   'MM2_-_Skull_Castle_1_Remix.mid',
#   'mggbcmm.mid',
#   'DW3TOWER.mid',
#   'T_Ryga13.mid',
#   'Kirby11.mid',
#   'PinkFlash.mid',
#   'LAoverworld.mid',
#   'megaman2.mid',
#   'Kdlflt.mid',
#   'fatwario.mid',
#   'BombFireWorks.mid',
#   'SMB3_Water_Land.mid',
#   'z2-palace.mid',
#   'Metroid_2_Dome_String_Quartet_dw (1).mid',
#   'Kbblvl01.mid',
#   'PkmRB-Forest (1).mid',
#   'Mm5end.mid',
#   'takeshi.mid',
#   'Track_and_Field_II_-_Hang_Gliding.mid',
#   'chip-and-dale-bonus.mid',
#   'rmtitle.mid',
#   'ZLA_Mabe_Pianos.mid',
#   'CVlegends_Final_stage.mid',
#   'GeminiMan.mid',
#   'mm4boss.mid',
#   'Venus.mid',
#   'sml_chaiworldremix.mid',
#   'DhwMM1wilycastle2.mid',
#   'JDC_SML1WX-3.mid',
#   'Uranus.mid',
#   'PkmGS-Battle3.mid',
#   'mario-underwater.mid',
#   'BoomerangKid-Title.mid',
#   'MKHHOUSE.mid',
#   'ff3jlb2.mid',
#   'lf-xfire.mid',
#   'palace3.mid',
#   'bcc1.mid',
#   'CVBR_-_New_Messiah.mid',
#   'Crystalis_Overworld_Remix.mid',
#   'wl-mainthemelvel.mid',
#   'WL2-mini-wario.mid',
#   'Mm2vict2.mid',
#   'ffl2mai4.mid',
#   'OldSchoolBrinstarDepths.mid',
#   'silvers2.mid',
#   'S-clear.mid',
#   'PkmGS-Ecruteak.mid',
#   'guarleg_boss2.mid',
#   'GB_Robocop_Lvl1.mid',
#   'Mm3vict2.mid',
#   'T_Rygar5.mid',
#   'GuardianLegend_Computer.mid',
#   'mcklvl1.mid',
#   'tsbvwhsc.mid',
#   'MM2WoodManv1.mid',
#   'A-sad (1).mid',
#   'T_CastleVania2Revenge_BossLevel (1).mid',
#   'Boss1_1.mid',
#   'PkmGS-Intro1.mid',
#   'tmnt2stg3.mid',
#   'arcadia.mid',
#   'f13cabinjason.mid',
#   'Hebereke-Boss1.mid',
#   'northsouth.mid',
#   'SMB3_Level1.mid',
#   'lava.mid',
#   'ng2_army.mid',
#   'desert.mid',
#   'SMB3_-_Koopa_Kid_Battle_-Remix-.mid',
#   'CB_Startropics.mid',
#   'airman1.mid',
#   'RR_Music1.mid',
#   'begining.mid',
#   'lalev1.mid',
#   'bmend.mid',
#   'PkmGS-Enc6.mid',
#   'skeetshooter.mid',
#   'ddcity.mid',
#   'T_Tsub17.mid',
#   'SMB3_Koopahari_Desert-KM.mid',
#   'cinnabar_mansion.mid',
#   'MMDaveTheme.mid',
#   'ddbridge.mid',
#   'Gwgtitle (1).mid',
#   'BlasterMaster.mid',
#   '16-WeaponPromo.mid',
#   'GSCElmsLab-1.mid',
#   'Sand_World.mid',
#   'recovery.mid',
#   'imm15.mid',
#   'Metroid2Theme.mid',
#   'Iceman-Nu_Style-Metal.mid',
#   'DKL_-_Zepplin_-Remix-.mid',
#   'RCR_-_A_Tougher_Fight_-Remix-.mid',
#   'PKMN_-_GymLeaderRemix.mid',
#   'ng2stg31.mid',
#   'bbcc2clock.mid',
#   'Pitfall_-_Prison.mid',
#   'jawsmain.mid',
#   'TCG_-_Trainer_Battle_Darkmind_V2.mid',
#   'LOZOoS_-_D2A.mid',
#   'Ml2over1.mid',
#   'bowser.mid',
#   'SuperMrioLand2-OverworldMap.mid',
#   'mm6-flameman-good.mid',
#   'drmending.mid',
#   'SMB3_-_Underwater_-Remix-.mid',
#   'BatmanNESlvl3.mid',
#   'Prolog4a.mid',
#   'SMB3_-_Overworld_1_-Remix-.mid',
#   'dkl3tree.mid',
#   'DW3VLLGE.mid',
#   'MM_Jeffs_Theme.mid',
#   'S-twinrv.mid',
#   'Ghosts_N_Goblins-Game_Over.mid',
#   'swords-titlescreen.mid',
#   'StarTropics-victory.mid',
#   'mm2-wood.mid',
#   'MarbleMadness1.mid',
#   'S-subros.mid',
#   'mm3psw.mid',
#   'wl2fctry.mid',
#   'ms_waltz.mid',
#   'Dive_Man.mid',
#   'DG_MM3_Magnetman.mid',
#   'T_WaiWaiWorld_Fuma.mid',
#   'ff3lastboss01.mid',
#   'T_SnakesRevenge_Escape.mid',
#   'Wily6.mid',
#   'nayru.mid',
#   'gaunt_a.mid',
#   'da_smb3-world1 (1).mid',
#   'WarriorofArgos(rygarj)area1.mid',
#   'G_rm4end.mid',
#   'lf-st6.mid',
#   'FF2magiciantower11.mid',
#   'sr_1stbuilding.mid',
#   'Z2level7.mid',
#   'pallettown.mid',
#   'ff1menu.mid',
#   'Nostalgie.mid',
#   'MM2-Flashmans_Stage_-_Conducted.mid',
#   'dkl2_barrel_bayou.mid',
#   'Dd3-map.mid',
#   'burn_the_wind.mid',
#   'dkltitle.mid',
#   'Snbrost2.mid',
#   'dd2-mission7.mid',
#   'lastempl.mid',
#   'Wario_Blast_-_Final_Boss.mid',
#   'mettitle.mid',
#   'Zelda_IV_DX_-_Color_Dungeon.mid',
#   'cv1-6.mid',
#   'Yukon-Pyramid.mid',
#   'dq4ragnar.mid',
#   'CDRR2_NES_Title_Screen.mid',
#   'DK-05-Desert.mid',
#   'Dw4death.mid',
#   'crystalis-fortress.mid',
#   'ffl1_op (1).mid',
#   'DDD2_-_Final_Boss.mid',
#   'dd2-mission3.mid',
#   'FF1-Matoyas_Cave02.mid',
#   'Sleep.mid',
#   'Wizards265.mid',
#   'Contra_-_Game_Over.mid',
#   'KirbyBlockBall.mid',
#   'Mm4weap.mid',
#   'kouha-lvl3.mid',
#   'z2town2.mid',
#   'ksstdmns.mid',
#   'kfdragon2_2.mid',
#   'GSCSelection.mid',
#   'smbdvscourses.mid',
#   'bubbleman(c-mix).mid',
#   'Mercury1_1ByCryogen.mid',
#   'bkgb_title_kio_7.mid',
#   'ng1_4-2.mid',
#   'DKworld7.mid',
#   'ff_pr.mid',
#   'Faxtw.mid',
#   'DW3CASTL.mid',
#   'CerulGM.mid',
#   'mm3sprkm.mid',
#   'DK-Boss.mid',
#   'Sml2th.mid',
#   'PRBLAVEN.mid',
#   'smb_overw.mid',
#   'Castlevania_Vampire_Killer.mid',
#   'Rin.mid',
#   'Gauntlet_SongC.mid',
#   'chaos_qt5up2.mid',
#   'lf-st2.mid',
#   'skate_or_die.mid',
#   'Cutman.mid',
#   'Mario_is_Missing_NES-Sydney_Austrailia.mid',
#   'BonusGame.mid',
#   'AdventuresOfLolo-Stage_Music.mid',
#   'smb3-cloud (1).mid',
#   'GBMarsByCryogen.mid',
#   'SMB3_The_Sky-KM.mid',
#   'TETRISmine.mid',
#   'Talespin_-_Boss.mid',
#   'Gbubblyclouds.mid',
#   'f13field.mid',
#   'PkmGS-Victory3.mid',
#   'HardMan.mid',
#   'Protoman.mid',
#   'Zanac_Game_Over.mid',
#   'smb2cs.mid',
#   'wl-lava.mid',
#   'mm3boss2X.mid',
#   'sorbigdukes.mid',
#   'x-tunnelscene.mid',
#   'GMM5napalmman.mid',
#   'DDII_-_IntoTheTurfRemix.mid',
#   'silius6v20.mid',
#   'ff3j-ew.mid',
#   'SwordsandSerpentsIntro.mid',
#   'd1select.mid',
#   'FF1_Chaos.mid',
#   'Jupiter.mid',
#   '28-Ending.mid',
#   'uninvit4.mid',
#   'PkmGS-Enc2.mid',
#   'chill.mid',
#   'T_WaiWaiWorld_KonamiGirl_GM.mid',
#   'c3stg2.mid',
#   'ww3knite.mid',
#   '11-WeaponPromo.mid',
#   'CVA_-_Darkness_-Remix-.mid',
#   'StarTropics-miracola.mid',
#   '12-WilyIntro.mid',
#   'junglestrike-title.mid',
#   'Sparkman27kb.mid',
#   'smlsky.mid',
#   'PowerbladeInterlude.mid',
#   'z1dungeon1.mid',
#   'Amagon-Area_Clear.mid',
#   'faxmwtk.mid',
#   'sr_password.mid',
#   'tetris.mid',
#   'Blaster_Master_Stage_II.mid',
#   'MetalstormLvl3.mid',
#   'drwilly1.mid',
#   'KrionConquest_Stage1.mid',
#   'kracko.mid',
#   'Orwin.mid',
#   'airman5.mid',
#   'ff2jbat2.mid',
#   'Hebereke-Password.mid',
#   'dtmoon.mid',
#   'GMM5selected.mid',
#   'BCEF_BossRoom.mid',
#   '14-WilyStage2.mid',
#   'gzilla_pluto.mid',
#   'T_DuckTales_TransylvaniaTheme.mid',
#   'PkmGS-Lab.mid',
#   'Ww-completestage.mid',
#   'Ml2star.mid',
#   'PkmGS-Battle7.mid',
#   'mm3selected.mid',
#   'Blastar2.mid',
#   'Rm3_Magnet.mid',
#   'LUF3FTS.mid',
#   'Heat1_0.mid',
#   'T_Rygar1.mid',
#   'T_RockMan_BombManTheme.mid',
#   'dq3credt.mid',
#   'MM3_Shadow_Man-KM.mid',
#   'Snakemandramatic.mid',
#   'qm2.mid',
#   'MM3-Magnet_Man.mid',
#   'GCVA_-_Boss_Dracula_phase_1.mid',
#   'T_SaGaLegend3_EventTheme03.mid',
#   'ffatwn1.mid',
#   'st2.mid',
#   'Double_Dragon-Cliffs.mid',
#   'ng3_3-1.mid',
#   'dklmountains.mid',
#   'T_NinjaGaiden_Balisk_Special.mid',
#   'KalinkaRmx.mid',
#   'smb2overworld1.mid',
#   'Kbblvl05.mid',
#   'ooa_ralph_dance.mid',
#   'PkmGS-Lavender.mid',
#   'GSCElmsLab.mid',
#   'DK-MiniBoss2.mid',
#   'TMNT2_-_FireXG.mid',
#   'SML-Ending.mid',
#   'Nintendo_World_Cup_-_Select.mid',
#   '13-WilyStage1.mid',
#   'smb3.mid',
#   'ready.mid',
#   'bbccb2.mid',
#   'AFLevel_End.mid',
#   'PKMNRT10.mid',
#   'Z4sword.mid',
#   'mm4cossack.mid',
#   'S-onoxc.mid',
#   'SRnR_-_Stage_04.mid',
#   'MM1_GutsMan.mid',
#   'rushifell-V1.2.mid',
#   'SMB3_-_Hammer_Bros_Battle_-Remix-.mid',
#   'ContraForceL2.mid',
#   'mario3overworld.mid',
#   'WickedChild(remix).mid',
#   'bmbr2battle.mid',
#   'Shadow_Shadow.mid',
#   'T_MegaMan5_DrLightTheme.mid',
#   'mario3end.mid',
#   'darkmatter.mid',
#   'Pokemon_Gold_Champion_SSBB_Remix_GS.mid',
#   'rmplace.mid',
#   'ff3airship.mid',
#   'wl2-minigames.mid',
#   'DW3JIPNG.mid',
#   'm2end.mid',
#   'PkmGS-Hall.mid',
#   'sohchrch.mid',
#   'WiztestWin.mid',
#   'AI3-Credits.mid',
#   'Crete_-_The_Island_Maze.mid',
#   'Prelude_GrandSymphony.mid',
#   'GameBoyCamera-DJ1.mid',
#   'Gyroman.mid',
#   'Sor(Nes)Track_1_(Fandago).mid',
#   'wily6_1a.mid',
#   'RidleysAnnoyingHideout.mid',
#   'SMB3_KoopahariDesert.mid',
#   '16-WilyIntro.mid',
#   'vball-titledemo.mid',
#   'JILost_-_Famicom_-_Akumajo_Densetsu_-_Beginning.mid',
#   'ff2battletheme.mid',
#   'lgmintro.mid',
#   'ninja_gaiden_5-3.mid',
#   'blizzardman.mid',
#   'ff1town1.mid',
#   'Mafat_Conspiracy-Act_5_Base.mid',
#   'Dw3_Credit.mid',
#   'T_HiryuNoKenII_StoryTheme.mid',
#   "Mars'_BGM.mid",
#   'MM_Michaels_Theme.mid',
#   'mm2bubbl.mid',
#   'mario09 (1).mid',
#   'MegaMan2_EndingPart1.mid',
#   'mm6wlyrb.mid',
#   'Pokemon_Route_12.mid',
#   'sml2booh.mid',
#   'c3pray.mid',
#   '01-TitleScreen.mid',
#   'SQ_mansion.mid',
#   'pbtheme.mid',
#   'bucky-redplanet.mid',
#   'Super_Mario_Brothers-Tropical_Mix.mid',
#   'T_BionicCommando_EnemyMapBattle.mid',
#   'GSCUnionCave.mid',
#   'FFl2_Boss_GB.mid',
#   'T_SnakesRevenge_Gameover.mid',
#   'gbc_smbd_sm01.mid',
#   'Tiny_Toon_Adventures!.mid',
#   'TranceRemains.mid',
#   'T_NinjaGaiden2_ALongWayToGo.mid',
#   'boh-redplanet.mid',
#   'Bbremiv2.mid',
#   'pgs-saff-gm.mid',
#   'smb2.mid',
#   'ff2jovrw.mid',
#   'SRnR_-_Stage_05.mid',
#   'z1overwarranged.mid',
#   'm2_cast.mid',
#   'gzilla_uranus.mid',
#   '10-Hardman.mid',
#   'TomSawyer-L1.mid',
#   'A-zora.mid',
#   'Megaman1bomermanstage-Dendog.mid',
#   'Z4boss.mid',
#   'mm5-introtitleXG.mid',
#   'Wario_Land_3_-_Golf.mid',
#   'MM_Cut_Man-KM.mid',
#   'Kbblvl04.mid',
#   'MM3_Snake_Man-KM.mid',
#   'mkii_zb_tomb_gb2.mid',
#   'Smb2brmx.mid',
#   'dw2.mid',
#   'Wizardry_II_Opening_Theme.mid',
#   'dk-die.mid',
#   'charge3_XG.mid',
#   'DrLightLabTheme.mid',
#   'tetris_b.mid',
#   'wl2-ruins1.mid',
#   'Goonies2-Good_Enough.mid',
#   'dq4alena.mid',
#   'mcklvl4.mid',
#   'Mars-X.mid',
#   'Metroid_2.mid',
#   'Sglake.mid',
#   'PkmGS-Battle6.mid',
#   'dtMoonx.mid',
#   'destearth_space.mid',
#   'W-zhenamuzh.mid',
#   'wcrew-g.mid',
#   'A-boss.mid',
#   'Goonice.mid',
#   'TopGun-select_missle.mid',
#   "let'sgo.mid",
#   'MKWORLD.mid',
#   'GQintro-V1.1.mid',
#   'Lalev4.mid',
#   'ff3jbat3.mid',
#   'pk_gs_newbarktown.mid',
#   'Castlevania_Legend-ps_ms.mid',
#   'MM2_Password_Screen-KM.mid',
#   'cstlv1s3.mid',
#   'TetrisBRemix.mid',
#   '02-Mm4Password.mid',
#   'dklbossr.mid',
#   'uwd_main.mid',
#   'Castlevania_Wicked_Child.mid',
#   'tecmo.mid',
#   ...])

# %%
def text_vector_to_midi(vector):
    """Generate midi from text vector.
    
    Args:
       vector: Vector with the index of the one-hot vector.
       
    Returns:
        MidiFile object.
    """
    ONE_HOT_MATRIX = np.eye(NUM_MIDI_PITCHES * 2 * NUM_TRACKS + NUM_TIMESHIFTS)
    vector_sequence = []
    for v in vector:
        vector_sequence.append(ONE_HOT_MATRIX[v])
    return vector_to_midi(vector_sequence)

# %%
vectors, names = get_training_vectors_from_file(training_filename)
name = '1999.mid'
index = names.index(name)
mid = text_vector_to_midi(vectors[index])
mid.save('txt' + name)
